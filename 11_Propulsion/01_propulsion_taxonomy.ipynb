# %% [markdown]
# # 11.1 — Propulsion System Taxonomy
#
# > *What propulsion technology propels the vehicle, and how is the right one chosen?*
#
# ```{note}
# 🚧 **This notebook is a placeholder.** Content will be written here. The topics and guiding questions below define the intended scope.
# ```
#
# ## Topics Covered
#
# - Piston engines: spark ignition (Avgas) and compression ignition (Diesel/Jet-A)
# - Gas turbine engines: turbojet, turbofan (low and high bypass), turboprop, turboshaft
# - Electric motors: BLDC, PMSM — with battery, fuel cell, or hybrid energy source
# - Hybrid-electric: series, parallel, turbo-electric (NASA STARC-ABL)
# - Rocket propulsion (ballistic/high-altitude)
# - Ramjet / scramjet: applicable regime (M > 2.5 for ramjet, M > 5 for scramjet)
#
# ## Guiding Questions
#
# 1. Why does turbofan bypass ratio dramatically affect specific fuel consumption and noise?
# 2. What is the 'power-to-weight' and 'energy-to-weight' distinction, and why does it matter for electric aircraft?
# 3. Why are turboshaft engines used in helicopters rather than turboprops or turbofans?
# 4. What is the 'turbo-electric' architecture and how does it differ from a hybrid-electric drivetrain?
