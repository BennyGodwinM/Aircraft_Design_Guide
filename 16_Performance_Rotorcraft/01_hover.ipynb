# %% [markdown]
# # 16.1 — Hover Performance
#
# > *How does the performance of rotary-wing vehicles differ fundamentally from fixed-wing?*
#
# ```{note}
# 🚧 **This notebook is a placeholder.** Content will be written here. The topics and guiding questions below define the intended scope.
# ```
#
# ## Topics Covered
#
# - Hover power required: momentum theory, ideal vs. induced vs. profile power
# - Figure of merit and its sensitivity to disk loading
# - OGE vs. IGE hover: the wall effect
# - Hover ceiling: density altitude limit for helicopter operations
# - Power loading curves: effect of rotor speed, blade number, twist
#
# ## Guiding Questions
#
# 1. Why does increasing disk loading (smaller rotor for same thrust) increase hover power so dramatically?
# 2. What physical mechanism causes ground effect to reduce power required in hover?
# 3. How is the hover ceiling (OGE) determined and what atmospheric conditions most severely limit it?
