# %% [markdown]
# # 16.3 — Multirotor UAV Performance
#
# > *How does the performance of rotary-wing vehicles differ fundamentally from fixed-wing?*
#
# ```{note}
# 🚧 **This notebook is a placeholder.** Content will be written here. The topics and guiding questions below define the intended scope.
# ```
#
# ## Topics Covered
#
# - Hover endurance: dominated by battery specific energy and motor/prop efficiency
# - Forward flight: transition from hover to cruise, aerodynamic efficiency
# - Payload-endurance trade-off for delivery drones
# - Wind sensitivity: effect of gusty conditions on battery drain
# - Discharge curves: capacity reduction at high C-rate
#
# ## Guiding Questions
#
# 1. Why do quadrotors typically achieve only 20–30 minutes of hover endurance regardless of battery capacity increases?
# 2. How does the advance ratio of a multirotor propeller change during transition to forward flight?
# 3. What C-rate is typical for a heavy-lift drone and why does it reduce available capacity?
