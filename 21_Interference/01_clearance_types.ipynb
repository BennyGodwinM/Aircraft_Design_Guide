# %% [markdown]
# # 21.1 — Types of Interference & Clearance
#
# > *How do we ensure that all components fit together correctly, with no unintended clashes, and appropriate clearances?*
#
# ```{note}
# 🚧 **This notebook is a placeholder.** Content will be written here. The topics and guiding questions below define the intended scope.
# ```
#
# ## Topics Covered
#
# - Hard interference (clash): two solid bodies occupying the same space — a design error
# - Soft interference (near-miss): components within a minimum clearance envelope
# - Functional clearance: thermal expansion, vibration, installation
# - Electrical clearance: high-voltage insulation distance requirements
# - Clearance types: static, dynamic (under load/thermal), installation clearance
#
# ## Guiding Questions
#
# 1. What is the difference between a hard and soft interference and which is more insidious in a complex assembly?
# 2. Why is a static clearance check alone insufficient and when must dynamic clearance analysis be performed?
# 3. What minimum clearance is typically required between hydraulic pipes and structural members?
