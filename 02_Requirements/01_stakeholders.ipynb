# %% [markdown]
# # 2.1 — Stakeholder Identification & Analysis
#
# > *Who has a stake in this vehicle, what do they need, and how do those needs become engineering requirements?*
#
# ```{note}
# 🚧 **This notebook is a placeholder.** Content will be written here. The topics and guiding questions below define the intended scope.
# ```
#
# ## Topics Covered
#
# - Primary stakeholders: operators, pilots, passengers, mission commanders
# - Secondary stakeholders: maintainers, ground crews, ATC, regulators
# - Tertiary stakeholders: communities (noise), insurers, financiers, the public
# - Stakeholder mapping: power vs. interest matrices
# - Conflicting stakeholder interests and how they are resolved
# - The role of the customer vs. the role of the user (especially in military programs)
#
# ## Guiding Questions
#
# 1. Who defines 'success' for a given aerial vehicle program, and how might their definitions conflict?
# 2. How does the stakeholder landscape differ between a commercial airliner, a military UAV, and a recreational drone?
# 3. What mechanisms exist to resolve conflicts between a paying customer and a regulatory authority?
# 4. Why are maintainers often the most neglected stakeholder in early design, and what are the consequences?
