# %% [markdown]
# # 2.2 — Needs, Goals & Objectives
#
# > *Who has a stake in this vehicle, what do they need, and how do those needs become engineering requirements?*
#
# ```{note}
# 🚧 **This notebook is a placeholder.** Content will be written here. The topics and guiding questions below define the intended scope.
# ```
#
# ## Topics Covered
#
# - Distinguishing needs from requirements
# - Operational Concept (CONOPS) development
# - Mission profiles: primary, secondary, contingency
# - Quantifying qualitative needs: turning 'fast' into a specific speed requirement
# - Goals vs. thresholds vs. objectives in defence acquisition (KPPs, KSAs, APAs)
#
# ## Guiding Questions
#
# 1. How do you translate a pilot's statement 'it must feel responsive' into a verifiable specification?
# 2. What is a CONOPS document and why must it precede requirements?
# 3. When is a requirement a threshold (minimum acceptable) vs. an objective (desired optimum)?
# 4. How do you avoid writing requirements that inadvertently over-specify the solution?
