# %% [markdown]
# # 7.4 — Rotor & Propeller Aerodynamics
#
# > *What physical principles govern the generation of lift, drag, and moments on aerial vehicles?*
#
# ```{note}
# 🚧 **This notebook is a placeholder.** Content will be written here. The topics and guiding questions below define the intended scope.
# ```
#
# ## Topics Covered
#
# - Actuator disk model: momentum theory in hover and forward flight
# - Figure of merit (FM) for rotors: ideal vs. actual hover efficiency
# - Blade element theory: local angle of attack, twist, taper optimisation
# - Combined BEMT: the workhorse for rotor design
# - Induced velocity distribution: uniform vs. non-uniform inflow
# - Blade-vortex interaction (BVI): the source of impulsive noise and vibration
# - Propeller efficiency vs. advance ratio (J); propeller vs. fan (ducted)
#
# ## Guiding Questions
#
# 1. What is the figure of merit (FM) for a helicopter rotor and what values are typical for modern designs?
# 2. How does BEMT differ from simple momentum theory and why is it necessary for blade design?
# 3. Why does twist improve hover efficiency but potentially hurt autorotation performance?
# 4. What is the physical mechanism of blade-vortex interaction?
# 5. Why does a ducted fan produce more thrust for the same diameter than an open rotor?
