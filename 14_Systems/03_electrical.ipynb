# %% [markdown]
# # 14.3 — Electrical Power Systems
#
# > *Beyond structure and aerodynamics, what systems must be integrated to make the vehicle function, and how do they interact?*
#
# ```{note}
# 🚧 **This notebook is a placeholder.** Content will be written here. The topics and guiding questions below define the intended scope.
# ```
#
# ## Topics Covered
#
# - Primary power generation: engine-driven generators, APU, RAT
# - AC vs. DC architecture: 115VAC/400Hz vs. 28VDC vs. 270VDC vs. 540VDC (HVDC)
# - Power distribution: busbars, contactors, protection (CBs, SSPCs)
# - Emergency power: batteries, RAT
# - Electrical load analysis and growth margins
# - eVTOL all-electric power systems: high-voltage bus, motor controllers
# - Lightning protection: zone classification, bonding, shielding
#
# ## Guiding Questions
#
# 1. Why is 270VDC HVDC preferred for more-electric aircraft over 115VAC/400Hz?
# 2. What is a Solid-State Power Controller (SSPC) and why is it replacing circuit breakers?
# 3. How is lightning strike protection designed into a carbon composite airframe?
# 4. What is the Electrical Load Analysis (ELA) document and why must it be revisited repeatedly?
