# %% [markdown]
# # 14.5 — Environmental Control System (ECS) & Life Support
#
# > *Beyond structure and aerodynamics, what systems must be integrated to make the vehicle function, and how do they interact?*
#
# ```{note}
# 🚧 **This notebook is a placeholder.** Content will be written here. The topics and guiding questions below define the intended scope.
# ```
#
# ## Topics Covered
#
# - Pressurisation: cabin altitude, pressure differential, FAR 25.841 requirements
# - Air conditioning: PAC (Pack Air Conditioning), bleed air vs. electric sources
# - Oxygen systems: chemical generators vs. gaseous vs. OBOGS
# - Thermal management for electronics: liquid cooling, heat exchangers
# - Cabin humidity and air quality: recirculation filters, HEPA
# - Pilot life support for fighters: OBOGS, G-suits, pressure breathing
#
# ## Guiding Questions
#
# 1. Why is 8,000 ft the maximum cabin altitude for a pressurised transport?
# 2. Why is bleed air being replaced by electrically powered ECS in new designs?
# 3. What is OBOGS and why has it largely replaced gaseous oxygen systems in modern fighters?
# 4. How is thermal management of avionics becoming a design driver for densely integrated cockpits?
