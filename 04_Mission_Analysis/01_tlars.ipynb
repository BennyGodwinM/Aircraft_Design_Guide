# %% [markdown]
# # 4.1 — Deriving TLARs from the Mission
#
# > *How does an operator's need become a set of precise numbers that engineers can design to?*
#
# ```{note}
# 🚧 **This notebook is a placeholder.** Content will be written here. The topics and guiding questions below define the intended scope.
# ```
#
# ## Topics Covered
#
# - Top-Level Aircraft Requirements (TLARs) defined
# - Range, payload, speed, altitude, MTOW as primary TLARs
# - Field performance requirements: takeoff and landing distance
# - Hover ceiling (rotorcraft), loiter endurance (UAVs)
# - The TLAR budget: how requirements compete for weight budget
# - Sensitivity analysis: which TLAR drives size most?
#
# ## Guiding Questions
#
# 1. How does a 10% increase in payload requirement propagate through the design to increase MTOW?
# 2. Why is the range requirement often the single biggest driver of fuel fraction and structural weight?
# 3. How is hover ceiling (HOGE) translated into a power loading requirement?
# 4. What is a 'rubber aircraft' study, and why is it useful at the TLAR stage?
