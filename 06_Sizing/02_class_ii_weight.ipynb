# %% [markdown]
# # 6.2 — Class II Weight Estimation (Component Build-Up)
#
# > *How big and how heavy will the vehicle be, even before we know its detailed shape?*
#
# ```{note}
# 🚧 **This notebook is a placeholder.** Content will be written here. The topics and guiding questions below define the intended scope.
# ```
#
# ## Topics Covered
#
# - Torenbeek method for structural component weights
# - Roskam Class II method: analytical equations for each component
# - Wing weight: effect of aspect ratio, sweep, taper, thickness
# - Fuselage weight: pressurised vs. unpressurised
# - Propulsion system weight: engine + accessories + fuel system
# - Systems weight: avionics, ECS, hydraulics, electrical
# - Iterative nature: weight estimate changes the design, which changes the weight
#
# ## Guiding Questions
#
# 1. Why does increasing aspect ratio reduce induced drag but increase wing weight, and where is the optimum?
# 2. How does cabin pressurisation add structural weight, and what does this imply for UAV design?
# 3. How is the 'snowball effect' in weight estimation managed?
