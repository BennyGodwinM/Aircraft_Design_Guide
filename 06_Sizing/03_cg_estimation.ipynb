# %% [markdown]
# # 6.3 — Center of Gravity Estimation & CG Travel
#
# > *How big and how heavy will the vehicle be, even before we know its detailed shape?*
#
# ```{note}
# 🚧 **This notebook is a placeholder.** Content will be written here. The topics and guiding questions below define the intended scope.
# ```
#
# ## Topics Covered
#
# - CG estimation from component weight and location
# - CG travel with fuel burn, payload variation, passenger boarding
# - Forward and aft CG limits: stability and control authority
# - CG envelope diagram (loading diagram)
# - Neutral point and static margin introduction
# - Specific CG challenges for helicopters: rotor CG vs. aircraft CG
#
# ## Guiding Questions
#
# 1. What defines the forward CG limit and what happens if it is exceeded?
# 2. How does the CG travel from MTOW to OEW as fuel burns, and how must stability be maintained throughout?
# 3. Why do helicopters have a much narrower CG envelope than fixed-wing aircraft?
# 4. What is 'CG margin' and how is it different from static margin?
