# %% [markdown]
# # 6.1 — First-Order Weight Estimation Methods
#
# > *How big and how heavy will the vehicle be, even before we know its detailed shape?*
#
# ```{note}
# 🚧 **This notebook is a placeholder.** Content will be written here. The topics and guiding questions below define the intended scope.
# ```
#
# ## Topics Covered
#
# - Class I (statistical) weight estimation: Raymer's regression equations
# - Raymer's MTOW sizing chart: range/endurance as function of payload fraction
# - Component weight fractions: wing, fuselage, empennage, landing gear, propulsion, systems
# - Historical aircraft data: weight fraction trends for different vehicle classes
# - Equivalent methods for helicopters: Tishchenko, Mil design bureau methods
# - UAV weight estimation: distinct trends from manned aircraft
#
# ## Guiding Questions
#
# 1. Why do statistical weight estimation methods work at all — what assumption underlies their accuracy?
# 2. How does the empty weight fraction trend change from small GA to large transport jets, and why?
# 3. Why are helicopter weight fractions fundamentally different from fixed-wing?
# 4. What are the limits of statistical methods when designing a truly novel vehicle configuration?
