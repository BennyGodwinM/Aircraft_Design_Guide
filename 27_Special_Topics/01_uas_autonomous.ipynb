# %% [markdown]
# # 27.1 — Autonomous & Uncrewed Systems (UAS)
#
# Covers UAS-specific design drivers: certification pathways (FAA Part 107 / EASA U-space), autopilot architecture and redundancy, sense-and-avoid (DAA) systems, communication link budgets, ground control station integration, and endurance vs. payload trade-offs unique to unmanned platforms.

# %% [markdown]
# ## UAS Classification & Regulatory Landscape
#
# <!-- TODO: Write content for this section -->
#
# **Key topics to cover:**
#
# - ICAO, FAA, and EASA UAS classification frameworks
# - Beyond visual line of sight (BVLOS) certification requirements
# - Remote ID and traffic management (UTM/U-space)

# %% [markdown]
# ## Design Drivers Unique to UAS
#
# <!-- TODO: Write content for this section -->
#
# **Key topics to cover:**
#
# - Removal of pilot-in-the-loop: weight and volume savings vs. autopilot mass
# - Communication link budget: latency, bandwidth, range, and spectrum allocation
# - Ground control station (GCS) integration and human-machine interface

# %% [markdown]
# ## Sense, Detect & Avoid (DAA) Systems
#
# <!-- TODO: Write content for this section -->
#
# **Key topics to cover:**
#
# - Active sensors: ADS-B, radar, TCAS adaptations for small UAS
# - Passive sensors: electro-optical, infrared cameras
# - DAA algorithms and well-clear volumes

# %% [markdown]
# ## Autopilot Architecture & Redundancy
#
# <!-- TODO: Write content for this section -->
#
# **Key topics to cover:**
#
# - Flight management systems for uncrewed platforms
# - Redundancy philosophy: dual/triple redundancy for safety-critical systems
# - Failure mode and effect analysis (FMEA) for autonomous systems

# %% [markdown]
# ```{bibliography}
# :filter: docname in docnames
# ```
