# %% [markdown]
# # 27.5 — Emerging Methods: Digital Engineering, ML & Optimisation
#
# Surveys the computational and data-driven methods reshaping modern aircraft design practice: multidisciplinary design optimisation, surrogate modelling, machine learning for aerodynamic prediction, digital thread / model-based systems engineering, and generative design.

# %% [markdown]
# ## Multidisciplinary Design Optimisation (MDO)
#
# <!-- TODO: Write content for this section -->
#
# **Key topics to cover:**
#
# - Problem formulation: coupled multi-discipline analysis (MDA)
# - Architecture patterns: multidisciplinary feasible (MDF), individual discipline feasible (IDF)
# - Common MDO frameworks: OpenMDAO, SUAVE, CEASIOM

# %% [markdown]
# ## Surrogate Modelling & Design of Experiments
#
# <!-- TODO: Write content for this section -->
#
# **Key topics to cover:**
#
# - When to use surrogates: expensive high-fidelity codes
# - Common surrogate types: Kriging, radial basis functions, polynomial response surfaces
# - Latin hypercube sampling and space-filling designs of experiments (DoE)

# %% [markdown]
# ## Machine Learning for Aerodynamic Prediction
#
# <!-- TODO: Write content for this section -->
#
# **Key topics to cover:**
#
# - Neural networks as drag/lift polars: training data from CFD databases
# - Physics-informed neural networks (PINNs) for flow field prediction
# - Limitations: extrapolation risk and interpretability in certified applications

# %% [markdown]
# ## Digital Thread & Model-Based Systems Engineering (MBSE)
#
# <!-- TODO: Write content for this section -->
#
# **Key topics to cover:**
#
# - Single-source-of-truth geometry: parametric CAD linked to analysis models
# - MBSE with SysML: requirements, functional, logical, and physical views
# - Digital twin concepts: as-designed vs. as-maintained model divergence

# %% [markdown]
# ## Generative Design & Topology Optimisation
#
# <!-- TODO: Write content for this section -->
#
# **Key topics to cover:**
#
# - Topology optimisation for structural components: SIMP and BESO methods
# - Additive manufacturing enabling unconventional structural topologies
# - Integration into conceptual and preliminary design workflows

# %% [markdown]
# ```{bibliography}
# :filter: docname in docnames
# ```
