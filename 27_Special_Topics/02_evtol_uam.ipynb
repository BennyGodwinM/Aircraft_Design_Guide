# %% [markdown]
# # 27.2 — eVTOL & Urban Air Mobility (UAM)
#
# Covers the design space unique to electric vertical takeoff and landing vehicles for urban transport: lift+cruise vs. tiltrotor vs. multirotor+wing configurations, hover-to-cruise aerodynamic transition, battery energy density constraints, noise as a primary design driver, and vertiport infrastructure considerations.

# %% [markdown]
# ## UAM Mission Profiles & Market Context
#
# <!-- TODO: Write content for this section -->
#
# **Key topics to cover:**
#
# - Intra-city vs. suburban route structures
# - Passenger capacity, range, and turnaround time requirements
# - Certification basis: FAA MOSAIC, AC 21.17-3, EASA SC-VTOL

# %% [markdown]
# ## eVTOL Configuration Taxonomy
#
# <!-- TODO: Write content for this section -->
#
# **Key topics to cover:**
#
# - Multirotor (pure electric hover, no fixed-wing lift)
# - Lift+cruise (dedicated hover rotors + cruise propulsor)
# - Tiltrotor and tiltwing: continuous aero transition
# - Vectored thrust: ducted fans and compound helicopter

# %% [markdown]
# ## Aerodynamic Transition: Hover to Forward Flight
#
# <!-- TODO: Write content for this section -->
#
# **Key topics to cover:**
#
# - Transition corridor definition and tilt-angle scheduling
# - Blade element momentum theory applied to tilting rotors
# - Aerodynamic interference between lifting surfaces during transition

# %% [markdown]
# ## Battery Sizing & Energy Constraints
#
# <!-- TODO: Write content for this section -->
#
# **Key topics to cover:**
#
# - Specific energy vs. specific power trade-off for lithium-ion and solid-state cells
# - Mission energy budget: hover, climb, cruise, reserve, and degradation margin
# - Pack-level vs. cell-level sizing; thermal management implications

# %% [markdown]
# ## Noise as a Primary Design Driver
#
# <!-- TODO: Write content for this section -->
#
# **Key topics to cover:**
#
# - Community noise metrics: A-weighted SPL, SEL, and DNL
# - Rotor noise sources: blade passing frequency, thickness noise, loading noise
# - Design strategies: tip speed reduction, blade count, and rotor phasing

# %% [markdown]
# ```{bibliography}
# :filter: docname in docnames
# ```
