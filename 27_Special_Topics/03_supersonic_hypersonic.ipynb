# %% [markdown]
# # 27.3 — Supersonic & Hypersonic Design
#
# Covers the additional physics and design considerations that emerge above Mach 1: wave drag, the area rule, shock-boundary-layer interactions, inlet design, thermal protection systems, and the structural challenges of sustained high-speed flight.

# %% [markdown]
# ## Supersonic Aerodynamics Primer
#
# <!-- TODO: Write content for this section -->
#
# **Key topics to cover:**
#
# - Shock wave types: normal, oblique, and bow shocks
# - Prandtl-Glauert and Ackeret theories for thin airfoil/wing lift and drag
# - Drag divergence Mach number and the transonic regime

# %% [markdown]
# ## Wave Drag & the Area Rule
#
# <!-- TODO: Write content for this section -->
#
# **Key topics to cover:**
#
# - Sources of wave drag: volume wave drag and lift-dependent wave drag
# - Whitcomb's transonic area rule: cross-sectional area distribution
# - Supersonic area rule and Sears-Haack body as the theoretical minimum

# %% [markdown]
# ## Inlet Design for Supersonic Flow
#
# <!-- TODO: Write content for this section -->
#
# **Key topics to cover:**
#
# - Normal shock, external compression, and mixed compression inlets
# - Variable geometry inlets: ramps, spikes, and bypass systems
# - Inlet performance metrics: total pressure recovery and capture area

# %% [markdown]
# ## Thermal Protection & High-Temperature Materials
#
# <!-- TODO: Write content for this section -->
#
# **Key topics to cover:**
#
# - Aerodynamic heating: stagnation temperature and recovery factor
# - Thermal protection system (TPS) concepts: ablative, ceramic, metallic
# - Material limits: aluminium, titanium, nickel superalloys, carbon-carbon

# %% [markdown]
# ## Hypersonic Considerations (M > 5)
#
# <!-- TODO: Write content for this section -->
#
# **Key topics to cover:**
#
# - Real gas effects and high-temperature chemistry
# - Viscous interaction and entropy layer
# - Waverider configurations and lift-to-drag in the hypersonic regime

# %% [markdown]
# ```{bibliography}
# :filter: docname in docnames
# ```
