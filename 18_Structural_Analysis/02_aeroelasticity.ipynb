# %% [markdown]
# # 18.2 — Aeroelasticity
#
# > *Given the load cases and material properties, how do we size the structural members?*
#
# ```{note}
# 🚧 **This notebook is a placeholder.** Content will be written here. The topics and guiding questions below define the intended scope.
# ```
#
# ## Topics Covered
#
# - Static aeroelasticity: divergence and control reversal
# - Dynamic aeroelasticity: flutter (bending-torsion coupling, wing-store flutter)
# - Flutter speed prediction: Theodorsen method, p-k method, matched-point solution
# - Structural damping and its role in flutter prediction accuracy
# - Panel flutter for supersonic aircraft
# - Ground vibration test (GVT) and flight flutter clearance
# - Whirl flutter for propellers and tiltrotors
#
# ## Guiding Questions
#
# 1. What is divergence and why does a forward-swept wing make it more critical?
# 2. What is flutter and what structural coupling between bending and torsion modes is required for it to occur?
# 3. Why must every new aircraft type be cleared for flutter before first flight?
# 4. What is whirl flutter and why is it uniquely critical for tiltrotor aircraft?
