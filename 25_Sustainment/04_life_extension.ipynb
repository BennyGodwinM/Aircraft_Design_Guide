# %% [markdown]
# # 25.4 — Life Extension & Structural Modifications
#
# > *How is the aircraft designed to be maintained efficiently over its operational life?*
#
# ```{note}
# 🚧 **This notebook is a placeholder.** Content will be written here. The topics and guiding questions below define the intended scope.
# ```
#
# ## Topics Covered
#
# - Ageing aircraft regulations: FAR 26, EASA Part 26
# - Widespread Fatigue Damage (WFD) limit of validity
# - Structural repair manual (SRM): allowable damage limits and repair schemes
# - Major repair vs. minor repair and the STC process
# - Aircraft economic life vs. structural life
#
# ## Guiding Questions
#
# 1. What is Widespread Fatigue Damage (WFD) and why did it prompt new ageing aircraft regulations?
# 2. What is the difference between a major and minor repair, and which requires regulatory approval?
# 3. How do airlines decide between retiring an ageing aircraft and extending its structural life?
