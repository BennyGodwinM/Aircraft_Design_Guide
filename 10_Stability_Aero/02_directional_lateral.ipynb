# %% [markdown]
# # 10.2 — Directional & Lateral Static Stability
#
# > *How do the aerodynamic forces and moments produced by the vehicle shape determine its intrinsic stability?*
#
# ```{note}
# 🚧 **This notebook is a placeholder.** Content will be written here. The topics and guiding questions below define the intended scope.
# ```
#
# ## Topics Covered
#
# - Cn,β: directional stability, contribution of vertical fin, fuselage, dorsal fin
# - Cl,β: dihedral effect — wing dihedral, sweep, high vs. low wing position
# - Roll-yaw coupling: Dutch roll, spiral, and how stability derivatives interact
# - Keel effect and its contribution to lateral stability
#
# ## Guiding Questions
#
# 1. Why does a high-wing configuration have inherently more dihedral effect than a low-wing?
# 2. What is the Dutch roll mode and why is it an objectionable handling characteristic?
# 3. How does wing sweep contribute to effective dihedral, and why does this create lateral-directional coupling?
