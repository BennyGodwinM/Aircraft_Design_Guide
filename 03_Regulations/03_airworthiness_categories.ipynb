# %% [markdown]
# # 3.3 — Airworthiness Categories & What They Demand
#
# > *What legal, safety, and regulatory frameworks govern the design, manufacture, and operation of aerial vehicles?*
#
# ```{note}
# 🚧 **This notebook is a placeholder.** Content will be written here. The topics and guiding questions below define the intended scope.
# ```
#
# ## Topics Covered
#
# - FAR Part 23 / CS-23: Normal, Utility, Acrobatic, Commuter categories
# - FAR Part 25 / CS-25: Transport category large commercial aircraft
# - FAR Part 27 / CS-27 and 29 / CS-29: Normal and Transport category rotorcraft
# - FAR Part 33 / CS-E: Engines; FAR Part 35: Propellers
# - EASA SC-VTOL: Novel VTOL aircraft
# - Military: MIL-SPEC, STANAG, DEF STAN equivalents
# - UAS/RPAS: FAA Part 107, EASA OPEN/SPECIFIC/CERTIFIED categories
# - Microlight / ultralight exemptions across jurisdictions
#
# ## Guiding Questions
#
# 1. What structural load factors are required under each certification category, and why do they differ?
# 2. Why was FAR Part 23 rewritten as a performance-based standard in 2017?
# 3. How does the EASA OPEN/SPECIFIC/CERTIFIED UAS framework classify risk?
# 4. What are the key differences between Part 27 and Part 29?
