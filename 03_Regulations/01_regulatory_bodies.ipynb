# %% [markdown]
# # 3.1 — Regulatory Bodies & Their Jurisdictions
#
# > *What legal, safety, and regulatory frameworks govern the design, manufacture, and operation of aerial vehicles?*
#
# ```{note}
# 🚧 **This notebook is a placeholder.** Content will be written here. The topics and guiding questions below define the intended scope.
# ```
#
# ## Topics Covered
#
# - ICAO: international SARPs, Annexes 1–19
# - FAA (USA): Title 14 CFR, Part 21/23/25/27/29/33/35, UAS Parts 107/108
# - EASA (Europe): CS-23, CS-25, CS-27, CS-29, CS-E, Special Conditions
# - CAAC, TCCA, CASA, CAA — national authorities
# - Military airworthiness: MIL-HDBK-516, DEF STAN 00-970, JSP 553
# - Bilateral agreements (BASA) for mutual recognition of certifications
# - Emerging frameworks: EASA SC-VTOL, FAA Part 23 revision, UAS-specific rules
#
# ## Guiding Questions
#
# 1. Why does ICAO publish standards but not enforce them, and who does?
# 2. How does a bilateral airworthiness agreement reduce certification costs for manufacturers?
# 3. What regulatory gap exists for novel vehicles like eVTOLs and how are authorities addressing it?
# 4. Why do military aircraft operate under different airworthiness rules than civil aircraft?
