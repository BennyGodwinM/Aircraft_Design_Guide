# %% [markdown]
# # 3.5 — Environmental & Noise Regulations
#
# > *What legal, safety, and regulatory frameworks govern the design, manufacture, and operation of aerial vehicles?*
#
# ```{note}
# 🚧 **This notebook is a placeholder.** Content will be written here. The topics and guiding questions below define the intended scope.
# ```
#
# ## Topics Covered
#
# - ICAO Annex 16: noise standards for subsonic jets and propeller aircraft
# - FAA FAR Part 36 and EASA CS-36 noise certification
# - Chapter 14 noise limits and cumulative noise metric (EPNdB)
# - Emission standards: ICAO Annex 16 Vol II — CO, HC, NOₓ, smoke, nvPM
# - CORSIA (Carbon Offsetting and Reduction Scheme for International Aviation)
# - Supersonic boom regulations
# - Urban air mobility noise challenges: psychoacoustics, tonal noise, BVI
# - EASA UAS geo-fencing and drone traffic management (UTM/U-space)
#
# ## Guiding Questions
#
# 1. Why is cumulative noise (approach + sideline + flyover) used rather than a single measurement point?
# 2. How does blade-vortex interaction noise make helicopter approach certification challenging?
# 3. What design features reduce combustor NOₓ and why do they sometimes conflict with reducing CO?
# 4. Why are noise regulations particularly critical for eVTOL operators planning urban routes?
