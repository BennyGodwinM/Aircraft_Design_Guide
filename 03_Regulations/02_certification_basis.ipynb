# %% [markdown]
# # 3.2 — Certification Basis & Type Certificate
#
# > *What legal, safety, and regulatory frameworks govern the design, manufacture, and operation of aerial vehicles?*
#
# ```{note}
# 🚧 **This notebook is a placeholder.** Content will be written here. The topics and guiding questions below define the intended scope.
# ```
#
# ## Topics Covered
#
# - The Type Certificate (TC) process: application, design approval, production approval
# - Supplemental Type Certificate (STC) for modifications
# - Certification Basis: applicable regulations at time of application
# - Means of Compliance (MoC): analysis, test, inspection, similarity, engineering judgement
# - Special Conditions for novel technologies
# - Equivalent Safety Findings and Exemptions
# - Production Approval (PAH) and POA under EASA
#
# ## Guiding Questions
#
# 1. Why does locking the certification basis early benefit manufacturers?
# 2. What triggers the need for a Special Condition rather than compliance with existing rules?
# 3. How does an Equivalent Safety Finding allow innovation while maintaining safety?
# 4. What is the difference between design approval and production approval?
