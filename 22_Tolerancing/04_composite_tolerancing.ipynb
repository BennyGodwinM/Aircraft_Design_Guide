# %% [markdown]
# # 22.4 — Tolerance Specification for Composites
#
# > *How do we specify allowable variation in dimensions to ensure parts fit, function, and are manufacturable?*
#
# ```{note}
# 🚧 **This notebook is a placeholder.** Content will be written here. The topics and guiding questions below define the intended scope.
# ```
#
# ## Topics Covered
#
# - Composite part dimensional variation: spring-back, cure shrinkage, ply-drop offsets
# - Tolerancing for CFRP parts: different from metals
# - Surface waviness and its aerodynamic effect on laminar flow
# - Co-cured vs. co-bonded vs. secondary bonded assemblies
# - Tooling tolerances: CTE mismatch between tool and part
#
# ## Guiding Questions
#
# 1. Why does a CFRP part spring back after release from the mould and how is this compensated in tooling design?
# 2. What is ply drop-off and how is its dimensional effect managed?
# 3. Why is surface waviness critical for laminar flow wings and what tolerance limit is typically imposed?
