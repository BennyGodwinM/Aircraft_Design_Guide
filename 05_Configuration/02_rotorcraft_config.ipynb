# %% [markdown]
# # 5.2 — Configuration Options for Rotorcraft
#
# > *What does the vehicle look like, at the broadest level, and why?*
#
# ```{note}
# 🚧 **This notebook is a placeholder.** Content will be written here. The topics and guiding questions below define the intended scope.
# ```
#
# ## Topics Covered
#
# - Single main rotor + tail rotor (conventional): advantages and limitations
# - Tandem rotor (Chinook): payload capacity, CG range, retreating blade limitations
# - Coaxial rotor (Kamov): compactness, torque cancellation, ABC rotor potential
# - Synchropter/intermeshing rotor (Kaman): simplicity, low torque reaction
# - Tip-jet rotor: mechanical complexity trade-offs
# - Compound helicopter: auxiliary thrust + auxiliary lift
# - The retreating blade stall limit and why it caps conventional helicopter speed
#
# ## Guiding Questions
#
# 1. Why does the single main rotor + tail rotor configuration dominate despite the tail rotor consuming ~10% of total power?
# 2. What is retreating blade stall, and how do compound helicopters extend the speed envelope?
# 3. How does a coaxial rotor achieve torque cancellation, and what are its disadvantages?
# 4. Why is the tandem configuration preferred for heavy-lift over single-main-rotor?
