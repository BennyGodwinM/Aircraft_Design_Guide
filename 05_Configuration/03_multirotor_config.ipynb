# %% [markdown]
# # 5.3 — Configuration Options for Multirotor UAVs
#
# > *What does the vehicle look like, at the broadest level, and why?*
#
# ```{note}
# 🚧 **This notebook is a placeholder.** Content will be written here. The topics and guiding questions below define the intended scope.
# ```
#
# ## Topics Covered
#
# - Quadrotor (X, + configurations): redundancy vs. motor geometry
# - Hexarotor and octorotor: failure tolerance and payload capacity
# - Coaxial multirotor: compactness for given thrust
# - Fixed vs. variable pitch multirotor: response bandwidth vs. mechanical complexity
# - Tilt-rotor and tilt-body designs (Zipline Zara, Beta ALIA)
# - Motor layout effects on controllability and response bandwidth
#
# ## Guiding Questions
#
# 1. Why does a quadrotor have no structural redundancy in motor failure, while a hexarotor can survive one motor loss?
# 2. What is the bandwidth limit of throttle-based control, and why does variable pitch break through it?
# 3. How does tilt-body vs. tilt-rotor affect the complexity and risk of transition to forward flight?
# 4. Why do large multirotors become increasingly inefficient and why does this favour tiltrotors at larger scales?
