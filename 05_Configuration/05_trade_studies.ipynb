# %% [markdown]
# # 5.5 — Qualitative Configuration Trade Studies
#
# > *What does the vehicle look like, at the broadest level, and why?*
#
# ```{note}
# 🚧 **This notebook is a placeholder.** Content will be written here. The topics and guiding questions below define the intended scope.
# ```
#
# ## Topics Covered
#
# - Pugh matrix / decision matrix for configuration selection
# - Weighted criteria: aerodynamic efficiency, structural simplicity, certification risk, manufacturing cost, operational flexibility
# - Technology Readiness Level (TRL) and its role in down-selecting configurations
# - Configuration freezing: when is it too late to change?
#
# ## Guiding Questions
#
# 1. How do you avoid bias in a Pugh matrix when the configuration has already been informally selected?
# 2. What is TRL, how is it defined (NASA TRL scale 1–9), and why does a low-TRL component introduce program risk?
# 3. What does 'configuration freeze' mean in a programme context, and what are the consequences of violating it?
