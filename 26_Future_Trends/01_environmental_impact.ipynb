# %% [markdown]
# # 26.1 — Aviation's Environmental Impact
#
# > *Where is aircraft design heading, and how must the industry change to address climate and technological challenges?*
#
# ```{note}
# 🚧 **This notebook is a placeholder.** Content will be written here. The topics and guiding questions below define the intended scope.
# ```
#
# ## Topics Covered
#
# - CO₂, NOₓ, water vapour, contrail-induced cirrus: radiative forcing
# - ICAO CORSIA: carbon offsetting mechanisms
# - ATAG net-zero 2050 commitment: what it requires
# - Noise footprint trends and community impact
# - Life-cycle assessment (LCA) for aircraft
#
# ## Guiding Questions
#
# 1. Why is NOₓ at cruise altitude a disproportionately larger climate concern than the same quantity at ground level?
# 2. What does CORSIA actually require of airlines and how is it enforced?
# 3. What would a net-zero aviation sector by 2050 actually require in terms of technology and fleet renewal?
