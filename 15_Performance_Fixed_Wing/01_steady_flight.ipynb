# %% [markdown]
# # 15.1 — Equations of Motion & Steady Flight
#
# > *What can this aircraft do, and how do its design parameters determine the performance numbers?*
#
# ```{note}
# 🚧 **This notebook is a placeholder.** Content will be written here. The topics and guiding questions below define the intended scope.
# ```
#
# ## Topics Covered
#
# - Forces in steady level flight: lift = weight, thrust = drag
# - Thrust required vs. thrust available curves
# - Power required vs. power available
# - Minimum power speed vs. minimum drag speed
# - Stall speed: function of CLmax, wing loading, air density
# - Maximum speed: thrust-limited vs. buffet-limited (transonic)
#
# ## Guiding Questions
#
# 1. Why is minimum power speed always lower than minimum drag speed, and which is more relevant for endurance?
# 2. How does density altitude affect both stall speed (IAS vs. TAS) and maximum speed in level flight?
# 3. Why does a propeller-driven aircraft have better endurance at a lower speed than minimum drag speed?
