# %% [markdown]
# # 15.3 — Range & Endurance
#
# > *What can this aircraft do, and how do its design parameters determine the performance numbers?*
#
# ```{note}
# 🚧 **This notebook is a placeholder.** Content will be written here. The topics and guiding questions below define the intended scope.
# ```
#
# ## Topics Covered
#
# - Breguet range equation: derivation and interpretation
# - Effect of altitude on range: Mach-altitude trade for transport jets
# - Long-range cruise (LRC) vs. max range cruise (MRC)
# - Endurance: loiter at minimum power speed
# - Range for electric aircraft: the energy fraction equation
# - Effect of wind: optimum altitude for jet streams
#
# ## Guiding Questions
#
# 1. Why does a jet achieve maximum range at a specific combination of altitude and Mach number?
# 2. How does a headwind affect optimal cruise altitude for a transport jet?
# 3. Why is the specific air range (SAR, nm/kg fuel) a more operationally useful metric than L/D?
