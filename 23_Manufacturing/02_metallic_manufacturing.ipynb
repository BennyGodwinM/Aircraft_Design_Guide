# %% [markdown]
# # 23.2 — Metallic Manufacturing Processes
#
# > *How are aircraft components made, and how should design decisions account for manufacturing feasibility and cost?*
#
# ```{note}
# 🚧 **This notebook is a placeholder.** Content will be written here. The topics and guiding questions below define the intended scope.
# ```
#
# ## Topics Covered
#
# - Machining: milling (3-axis, 5-axis), turning, EDM, grinding
# - Sheet metal forming: stretch forming, press forming, hydroforming, SPF
# - Forging: open-die, closed-die, isothermal — landing gear forgings
# - Casting: investment casting for complex shapes
# - Extrusions: stringer profiles, fuselage frames
# - Joining: riveting, welding (TIG, MIG, FSW), bonding
# - Surface treatment: anodising, chem-milling, shot-peening, corrosion protection
#
# ## Guiding Questions
#
# 1. Why is 5-axis CNC machining preferred for complex spar fittings over casting or forging?
# 2. What is Superplastic Forming (SPF) and what advantage does it offer?
# 3. Why is friction stir welding (FSW) transformative for aluminium fuselage construction?
# 4. What is chem-milling and why is it used to reduce weight of large aluminium skins?
