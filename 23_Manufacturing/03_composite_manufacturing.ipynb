# %% [markdown]
# # 23.3 — Composite Manufacturing Processes
#
# > *How are aircraft components made, and how should design decisions account for manufacturing feasibility and cost?*
#
# ```{note}
# 🚧 **This notebook is a placeholder.** Content will be written here. The topics and guiding questions below define the intended scope.
# ```
#
# ## Topics Covered
#
# - Manual lay-up: wet lay-up, prepreg hand lay-up
# - Automated Fibre Placement (AFP): robotic, ply-by-ply, controlled path
# - Automated Tape Laying (ATL): flat and contoured panels
# - Resin Transfer Moulding (RTM): closed mould, high fibre volume fraction
# - Vacuum-Assisted RTM (VARTM): out-of-autoclave (OOA) alternative
# - Autoclave cure: temperature-pressure cycle, consolidation, void content
# - Out-of-autoclave prepreg: OOA prepreg systems
# - Filament winding: cylindrical pressure vessels, COPV
# - Inspection: ultrasonic testing (UT), thermography, X-ray CT
#
# ## Guiding Questions
#
# 1. Why is automated fibre placement (AFP) preferred over manual lay-up for primary structure?
# 2. What void content level is acceptable in a CFRP primary structure and how is it measured?
# 3. What is the major advantage of Out-of-Autoclave (OOA) processes over autoclave cure?
# 4. How does Resin Transfer Moulding reduce manufacturing labour and improve dimensional accuracy?
