# %% [markdown]
# # 17.2 — Dynamic Longitudinal Stability
#
# > *How does the vehicle respond to disturbances, and what makes it naturally stable or unstable?*
#
# ```{note}
# 🚧 **This notebook is a placeholder.** Content will be written here. The topics and guiding questions below define the intended scope.
# ```
#
# ## Topics Covered
#
# - Short period mode: high frequency, pitch oscillation, requires adequate damping
# - Phugoid mode: long period, altitude/speed exchange, lightly damped
# - Short period frequency and damping requirements (MIL-SPEC, handling qualities)
# - Cooper-Harper rating scale for handling qualities
#
# ## Guiding Questions
#
# 1. Why is the short period mode more important for pilot workload than the phugoid?
# 2. What damping ratio is considered adequate for the short period mode in a fighter vs. a transport?
# 3. What does a Cooper-Harper rating of 6 mean operationally?
