# %% [markdown]
# # 17.3 — Lateral-Directional Dynamic Stability
#
# > *How does the vehicle respond to disturbances, and what makes it naturally stable or unstable?*
#
# ```{note}
# 🚧 **This notebook is a placeholder.** Content will be written here. The topics and guiding questions below define the intended scope.
# ```
#
# ## Topics Covered
#
# - Dutch roll mode: combined yaw-roll oscillation
# - Roll subsidence: first-order roll response
# - Spiral mode: slow, often divergent
# - Yaw damper: suppressing Dutch roll for passenger comfort
# - Coupling: dihedral effect, directional stability, and their interaction
#
# ## Guiding Questions
#
# 1. Why is the Dutch roll mode objectionable even when it is technically stable?
# 2. Why are transport aircraft permitted a weakly spiral-unstable mode under FAR 25?
# 3. What does a yaw damper do to the Dutch roll eigenvalue, and how does it work physically?
